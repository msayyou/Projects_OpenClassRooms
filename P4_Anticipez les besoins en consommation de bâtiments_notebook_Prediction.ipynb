# %% [markdown]
# <h1>Content table<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objectif-de-l'étude" data-toc-modified-id="Objectif-de-l'étude-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objectif de l'étude</a></span><ul class="toc-item"><li><span><a href="#Mission" data-toc-modified-id="Mission-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Mission</a></span></li></ul></li><li><span><a href="#Importation-des-librairies-et-fonctions" data-toc-modified-id="Importation-des-librairies-et-fonctions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importation des librairies et fonctions</a></span><ul class="toc-item"><li><span><a href="#Librairies" data-toc-modified-id="Librairies-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Librairies</a></span></li><li><span><a href="#Les-fonctions" data-toc-modified-id="Les-fonctions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Les fonctions</a></span></li><li><span><a href="#Lecture-du-jeux-de-données" data-toc-modified-id="Lecture-du-jeux-de-données-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Lecture du jeux de données</a></span></li></ul></li><li><span><a href="#Test-des-modèles-de-prédiction:--Supervised-Model-:-Regression" data-toc-modified-id="Test-des-modèles-de-prédiction:--Supervised-Model-:-Regression-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Test des modèles de prédiction:  Supervised Model : Regression</a></span><ul class="toc-item"><li><span><a href="#Variabe-dépendante-:-TotalGHGEmissions-(-Emission-de-CO2)" data-toc-modified-id="Variabe-dépendante-:-TotalGHGEmissions-(-Emission-de-CO2)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Variabe dépendante : TotalGHGEmissions ( Emission de CO2)</a></span><ul class="toc-item"><li><span><a href="#VIF-(Variance-Inflation-Factor)--Analyse-de-la-Multicolinéarité" data-toc-modified-id="VIF-(Variance-Inflation-Factor)--Analyse-de-la-Multicolinéarité-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>VIF (Variance Inflation Factor)- Analyse de la Multicolinéarité</a></span></li><li><span><a href="#Test-des-Algorithmes" data-toc-modified-id="Test-des-Algorithmes-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Test des Algorithmes</a></span></li><li><span><a href="#Traing-&amp;-testing-set" data-toc-modified-id="Traing-&amp;-testing-set-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Traing &amp; testing set</a></span></li><li><span><a href="#Linear-Regression-avec-Statsmodels-:-Ordinary-Least-Squares-(OLS)" data-toc-modified-id="Linear-Regression-avec-Statsmodels-:-Ordinary-Least-Squares-(OLS)-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Linear Regression avec Statsmodels : Ordinary Least Squares (OLS)</a></span></li><li><span><a href="#Sickit-learn-Algorithmes" data-toc-modified-id="Sickit-learn-Algorithmes-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Sickit-learn Algorithmes</a></span><ul class="toc-item"><li><span><a href="#K-fold-Cross-validation(CV)-et-GridSearchCV" data-toc-modified-id="K-fold-Cross-validation(CV)-et-GridSearchCV-3.1.5.1"><span class="toc-item-num">3.1.5.1&nbsp;&nbsp;</span>K-fold Cross-validation(CV) et GridSearchCV</a></span></li><li><span><a href="#Comparaison-des-Algoritmes" data-toc-modified-id="Comparaison-des-Algoritmes-3.1.5.2"><span class="toc-item-num">3.1.5.2&nbsp;&nbsp;</span>Comparaison des Algoritmes</a></span></li><li><span><a href="#Learning-Curve" data-toc-modified-id="Learning-Curve-3.1.5.3"><span class="toc-item-num">3.1.5.3&nbsp;&nbsp;</span>Learning Curve</a></span></li><li><span><a href="#Prédiction-Test-Score" data-toc-modified-id="Prédiction-Test-Score-3.1.5.4"><span class="toc-item-num">3.1.5.4&nbsp;&nbsp;</span>Prédiction Test Score</a></span></li></ul></li><li><span><a href="#Features-importance-with-SHAP" data-toc-modified-id="Features-importance-with-SHAP-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Features importance with SHAP</a></span></li></ul></li><li><span><a href="#Variable-dépendante-:-SiteEnergyUse(kBtu)" data-toc-modified-id="Variable-dépendante-:-SiteEnergyUse(kBtu)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Variable dépendante : SiteEnergyUse(kBtu)</a></span><ul class="toc-item"><li><span><a href="#VIF-(Variance-Inflation-Factor)" data-toc-modified-id="VIF-(Variance-Inflation-Factor)-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>VIF (Variance Inflation Factor)</a></span></li><li><span><a href="#Test-des-Algorithmes" data-toc-modified-id="Test-des-Algorithmes-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Test des Algorithmes</a></span><ul class="toc-item"><li><span><a href="#Training-&amp;-testing-set" data-toc-modified-id="Training-&amp;-testing-set-3.2.2.1"><span class="toc-item-num">3.2.2.1&nbsp;&nbsp;</span>Training &amp; testing set</a></span></li></ul></li><li><span><a href="#Ordinary-Least-Squares-(OLS)-Regression-In-Statsmodels" data-toc-modified-id="Ordinary-Least-Squares-(OLS)-Regression-In-Statsmodels-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Ordinary Least Squares (OLS) Regression In Statsmodels</a></span></li><li><span><a href="#Sckit-learn-Algorithmes" data-toc-modified-id="Sckit-learn-Algorithmes-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Sckit-learn Algorithmes</a></span><ul class="toc-item"><li><span><a href="#K-fold-Cross-validation-&amp;-GridSearchCV" data-toc-modified-id="K-fold-Cross-validation-&amp;-GridSearchCV-3.2.4.1"><span class="toc-item-num">3.2.4.1&nbsp;&nbsp;</span>K-fold Cross validation &amp; GridSearchCV</a></span></li><li><span><a href="#Comparaison-des-algorithmes" data-toc-modified-id="Comparaison-des-algorithmes-3.2.4.2"><span class="toc-item-num">3.2.4.2&nbsp;&nbsp;</span>Comparaison des algorithmes</a></span></li><li><span><a href="#Learning-Curve" data-toc-modified-id="Learning-Curve-3.2.4.3"><span class="toc-item-num">3.2.4.3&nbsp;&nbsp;</span>Learning Curve</a></span></li><li><span><a href="#Prediction-Test-Score" data-toc-modified-id="Prediction-Test-Score-3.2.4.4"><span class="toc-item-num">3.2.4.4&nbsp;&nbsp;</span>Prediction Test Score</a></span></li></ul></li><li><span><a href="#Feature-Importance-using-shap" data-toc-modified-id="Feature-Importance-using-shap-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Feature Importance using shap</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Objectif de l'étude

# %% [markdown]
# La ville de Seattle s’intéresse de près aux émissions des bâtiments non destinés à l’habitation d'ici 2050. Des relevés minutieux ont été effectués en 2015 et en 2016. Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, nous devons tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments pour lesquels elles n’ont pas encore été mesurées. Aussi nous devons évaluer l’intérêt de l’"ENERGY STAR Score" pour la prédiction d’émissions.

# %% [markdown]
# ## Mission

# %% [raw]
# 1- Réaliser une courte analyse exploratoire.
# 2- Tester différents modèles de prédiction afin de répondre au mieux à la problématique.

# %% [markdown]
# # Importation des librairies et fonctions

# %% [markdown]
# ## Librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
sns.set_style("whitegrid")
sns.color_palette("crest", as_cmap=True)
import ast
from matplotlib import pyplot as plt
import seaborn as sns
import math
from sklearn.linear_model import LinearRegression
from sklearn import datasets
from sklearn import preprocessing
from sklearn.metrics import r2_score , mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
import scipy.optimize as opt
from sklearn import preprocessing
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import RidgeCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import validation_curve
from sklearn.metrics import accuracy_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn import utils
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import RANSACRegressor, LinearRegression,TheilSenRegressor
from scipy.stats import norm, skew
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import sklearn.linear_model as lm
from pandas.plotting import scatter_matrix
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance
from yellowbrick.features import (FeatureImportances)
import matplotlib.pyplot as plt


from numpy import arange
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, make_scorer, r2_score
from sklearn.metrics import explained_variance_score,mean_absolute_error,r2_score
from numpy import absolute
import warnings
warnings.filterwarnings("ignore")
! pip install shap
import shap
shap.initjs()
from shap.plots import _waterfall
# Out:
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sayyou mvhs\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# ## Les fonctions

# %%
def nbr_lignes(data):
       return len(data)
    
def nbr_columns(data):
    return len(data.columns)

#fonction qui concerne les lignes dupliquées + % 
def count_duplicates_rows(data):    
    return len(data)-len(data.drop_duplicates())

def count_duplicates_rows_percent(data):
    return count_duplicates_rows(data)/nbr_lignes(data)

# fonction qui excute une trame de données en entrée et renvoie le nombre de cellules manquantes + %
def cellules_manquantes(data):
    return data.isna().sum().sum()

#fonction prenant une dataframe en entrée et renvoie le pourcentage de cellules manquantes
def cellules_manquantes_percent(data):
    return data.isna().sum().sum()/(data.size)

# fonction qui renvoie le nom de la variable dans l’espace de noms 
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

#fonction qui renvoi les variables en dataframe
def dataset_columns(data):
    print('--------------------------------------------------------------------------')
    print('Data : {}'.format(namestr(data, globals())))
    print('Columns : {}'.format(data.columns.values))


# Fonction permattant de calculer la somme et le pourcentage des valeurs manquantes 

def missing_values_1(df):

    total = df.isnull().sum()   # Calcul du total des valeurs manquantes
    percent = round(df.isnull().sum()/df.isnull().count()*100,1) # Calcul le pourcentage des valeurs arrondi
      
    missing_data = pd.concat([total,percent],axis =1, keys=['Total','Ratio_of_NA(%)']) 
    type=pd.DataFrame(df[missing_data.index].dtypes, columns=['Types'])
    missing_data=pd.concat([missing_data,type],axis=1)
    missing_data=missing_data.sort_values('Total',ascending=False)
    missing_data.head(15)
    print( "le total des valeurs manquantes est", total.sum()) #Afficher la somme total des valeurs manquantes
    print(percent) #afficher le poucentage
    print(missing_data.head())
    print()
    print(set(missing_data['Types']))
    print()
    print("---Categorical columns---")
    
    print(missing_data[missing_data['Types']=="object"].index) # Colonnes ayant des variables qualitatives
    print()
    print("---Numerical columns----")
    print(missing_data[missing_data['Types'] !="object"].index)  # Colonnes ayant des variables quantitatives
    
    
# fonction qui prend le trame de données en entrée et en sortie un cadre de données contenant des variables, le nombre de valeurs manquantes et le % de valeurs manquantes'''
def missing_values(data):
    summary = pd.DataFrame(columns=['Variable name', 'Missing values', '% Missing'])
    summary['Variable name']=data.columns
    missing = list()
    percent_missing = list()
    for var in data.columns:
        nb_missing = cellules_manquantes(data[var])
        pc_missing = cellules_manquantes_percent(data[var])
        missing.append(nb_missing)
        percent_missing.append(pc_missing)
    summary['Missing values'] = list(missing)
    summary['% Missing'] = list(percent_missing)
    return summary

# fonction qui génère la sortie de la méthode columns_type dans le fichier csv 
def output_dataframe_variable_types(data):
   
    summary = columns_type(data)
    summary.to_csv('output_dataframe_{}_variable_types.csv'.format(namestr(data, globals())),sep=',', index = False)
    

# fonction vue d'ensemble de la DataFrame: résumé contenant nombre de lignes, de colonnes, de cellules manquantes et de lignes en double
   
def data_set_overview(data):    
    print('--------------------------------------------------------------------------')
    print('Data : {}'.format(namestr(data, globals())))
    print('Nbr de variables : {}'.format(nbr_columns(data)))
    print('Nbr d observations : {}'.format(nbr_lignes(data)))
    print('cellules_manquantes : {}'.format(cellules_manquantes(data)))
    print('cellules_manquantes in % : {:.2%}'.format(cellules_manquantes_percent(data)))
    print('Duplicate rows : {}'.format(count_duplicates_rows(data)))
    print('Duplicate rows in % : {:.2%}'.format(count_duplicates_rows_percent(data)))
    

def search_componant(df, suffix=None):
    componant = []
    for col in df.columns:
        if suffix in col: 
            componant.append(col)
    return componant
    
  
# Fonction prenant une trame de données en entrée et renvoyant un résumé contenant nom de la variable, type
def columns_type(data): 
    
    df = pd.DataFrame(data.dtypes)[0]
    summary = pd.DataFrame(columns=['noms Variables', 'type Variable'])
    summary['noms Variables']=data.columns
    summary['type Variable']=list(df)
    return summary

   
def drop_unpopulated_column(data,limit):
    summary = missing_values(data)
    logical = list()
    for row in summary.iterrows():
        if float(row[1]['% Missing'])>float(limit):
            # to be dropped
            print('Dropping variable {} from  {} with % missing {}'.format(row[1]['Variable name'],namestr(data, globals()),round(float(row[1]['% Missing']),2)))
            logical.append(False)
        else:
            #kept
            logical.append(True)
        
    columns_to_keep = summary[logical]['Variable name']
    
    return data[columns_to_keep]


#Crée rapidement des DataFrame
def make_df(columns, index):
    
    data = {c: [str(c) + str(i) for i in index]
            for c in cols}
    return pd.DataFrame(data, index)

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %% [markdown]
# ## Lecture du jeux de données

# %%
final_df=pd.read_csv('data_finale.csv')

# %%
missing_values_1(final_df)
# Out:
# le total des valeurs manquantes est 0
# OSEBuildingID                                      0.0
# ENERGYSTARScore                                    0.0
# TotalGHGEmissions                                  0.0
# Source_EUI_GFABuilding                             0.0
# energy_per_GFABuilding                             0.0
# PropertyGFAParking                                 0.0
# NumberofFloors                                     0.0
# SiteEnergyUse(kBtu)                                0.0
# SteamUse(kBtu)                                     0.0
# NaturalGas(kBtu)                                   0.0
# Age                                                0.0
# PrimaryPropertyType_Hospital                       0.0
# PrimaryPropertyType_Hotel                          0.0
# PrimaryPropertyType_K-12 School                    0.0
# PrimaryPropertyType_Laboratory                     0.0
# PrimaryPropertyType_Large Office                   0.0
# ...

# %% [markdown]
# # Test des modèles de prédiction:  Supervised Model : Regression

# %% [markdown]
# ## Variabe dépendante : TotalGHGEmissions ( Emission de CO2)

# %% [markdown]
# ### VIF (Variance Inflation Factor)- Analyse de la Multicolinéarité

# %% [raw]
# La variable dépendante doit avoir une relation étroite avec les variables indépendantes.Cependant, mais les variables indépendantes ne doivent pas avoir de fortes corrélations entre d'autres variables indépendantes, ce qui nous appelons la  multicolinéarité . Dans le cas écheant, nous devons utiliser une seule parmi les variables indépendantes corrélées.
#
# Le VIF est un indicateur de l'existence de la multicolinéarité. la règle empirique pour l'existence possible d'une multicolinéarité élevée est quand la variable indépendante a une valeur supérieure à 10

# %% [raw]
# Comment interpréter les valeurs VIF
# La valeur de VIF commence à 1 et n'a pas de limite supérieure. Une règle générale pour l'interprétation des VIF est la suivante :
#
# Une valeur de 1 indique qu'il n'y a pas de corrélation entre une variable explicative donnée et toute autre variable explicative du modèle.
# Une valeur entre 1 et 5 indique une corrélation modérée entre une variable explicative donnée et d'autres variables explicatives dans le modèle, mais cela n'est souvent pas assez grave pour nécessiter une attention particulière.
#
# Une valeur supérieure à 5-10 indique une corrélation potentiellement sévère entre une variable explicative donnée et d'autres variables explicatives du modèle. Dans ce cas, les estimations des coefficients et les valeurs de p dans le résultat de la régression ne sont probablement pas fiables.
#
# Étant donné que chacune des valeurs VIF des variables explicatives de notre modèle de régression est proche de 1, la multicolinéarité est un problème dans notre exemple.

# %%
# Séparation du jeux de donnée pour le VIF
z=final_df.drop(['TotalGHGEmissions','SiteEnergyUse(kBtu)'],axis=1) # variables indépendantes
w= final_df['TotalGHGEmissions']# variable dépendante

# %%
#  Calcul de la Variance Inflation Factor (VIF)
vif_info = pd.DataFrame()
vif_info['VIF'] = [variance_inflation_factor(z.values, i) for i in range(z.shape[1])]
vif_info['Column'] = z.columns 
vif_info.sort_values('VIF', ascending=False)
# Out:
#          VIF                                           Column
# 1   8.886873                                  ENERGYSTARScore
# 3   6.233437                           energy_per_GFABuilding
# 2   5.804530                           Source_EUI_GFABuilding
# 8   3.907138                                              Age
# 24  3.317881  PrimaryPropertyType_Small- and Mid-Sized Office
# 17  3.082039                        PrimaryPropertyType_Other
# 0   3.045652                                    OSEBuildingID
# 13  2.858140                 PrimaryPropertyType_Large Office
# 5   2.356759                                   NumberofFloors
# 27  2.073780                    PrimaryPropertyType_Warehouse
# 11  2.068643                  PrimaryPropertyType_K-12 School
# 15  1.860950           PrimaryPropertyType_Mixed Use Property
# 4   1.708711                               PropertyGFAParking
# 21  1.669170                 PrimaryPropertyType_Retail Store
# ...

# %%
# supression
thresh=5
final_variables =vif_info[vif_info['VIF']> thresh]
final_variables
# Out:
#         VIF                  Column
# 1  8.886873         ENERGYSTARScore
# 2  5.804530  Source_EUI_GFABuilding
# 3  6.233437  energy_per_GFABuilding

# %%
#Suppression des variables qui représentent une corrélation plus que 5, tout en gardant ENERGYSTARSCORE 
final_df.drop(['Source_EUI_GFABuilding','energy_per_GFABuilding','ENERGYSTARScore'], axis=1,inplace=True)

# %% [markdown]
# ### Test des Algorithmes

# %% [raw]
# On peut réaliser des régressions linéaires de beaucoup de manières avec Python. les plus connu sont statsmodels et scikit-learn. Les deux librairies ont chacunes leurs qualités et leurs défauts, sachez que l’une est plus orienté data science et l’autre plus pour des économistes.
#
# OLS essaye d'ajuster une ligne de régression qui minimiserait le carré de la distance à partir de la ligne de régression

# %% [markdown]
# ### Traing & testing set

# %%
# Séparation du jeux de donnée 
X=final_df.drop(['TotalGHGEmissions','SiteEnergyUse(kBtu)'],axis=1) # variables indépendantes
y= final_df['TotalGHGEmissions']# variable dépendante

# %%
# Séparation Training set / testing Set+ paramètres
test_size = 0.20
seed = 7
num_folds = 10
scoring = 'r2'
scoring1='neg_mean_squared_error'
param_grid =dict()
random_state=42
n_repeats=10
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=seed)

# %%
#Shape
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (1296, 26)
# (324, 26)
# (1296,)
# (324,)

# %% [markdown]
# ###  Linear Regression avec Statsmodels : Ordinary Least Squares (OLS)

# %%
#ajout d'une constante aux variables prédictives
X = sm.add_constant(X)

#fit linear regression model
model = sm.OLS(y,X)
results = model.fit()

# Résultat
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      TotalGHGEmissions   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     3025.
# Date:                Wed, 18 May 2022   Prob (F-statistic):               0.00
# Time:                        14:59:02   Log-Likelihood:                 5894.3
# No. Observations:                1620   AIC:                        -1.173e+04
# Df Residuals:                    1593   BIC:                        -1.159e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Sickit-learn Algorithmes

# %%
# Algoritmes misent en comparaison
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('RDG', Ridge()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('GBR', GradientBoostingRegressor()))
models.append(('ETR', ExtraTreesRegressor()))
models.append(('RFR', RandomForestRegressor()))
models.append(('XGBR', XGBRegressor()))

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=seed)

# %% [markdown]
# #### K-fold Cross-validation(CV) et GridSearchCV

# %%
# Evaluation des models : K fold Cross-validation(CV) et GridSearchCV
results = []
names = []
for name, model in models:
    Kfold = RepeatedKFold(n_splits=num_folds,n_repeats=n_repeats, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=Kfold, scoring=scoring)
    cv_results1 = GridSearchCV(estimator=model,cv=Kfold,scoring='neg_mean_squared_error',
                               refit='neg_mean_squared_error',param_grid=param_grid,n_jobs = -1)
    grid = cv_results1.fit(X_train,y_train)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f) (%f)" % (name, absolute(grid.best_score_),cv_results.mean(), cv_results.std() )
    print(msg)
# Out:
# LR: 0.000078 (0.951927) (0.055909)
# LASSO: 0.002304 (-0.036057) (0.108011)
# RDG: 0.000757 (0.752914) (0.194528)
# EN: 0.002304 (-0.036057) (0.108011)
# KNN: 0.001607 (0.236666) (0.433920)
# CART: 0.000581 (0.811214) (0.212920)
# GBR: 0.000570 (0.868800) (0.160890)
# ETR: 0.000583 (0.880224) (0.157550)
# RFR: 0.000572 (0.874258) (0.149554)
# XGBR: 0.000562 (0.864638) (0.160346)

# %% [markdown]
# #### Comparaison des Algoritmes

# %%
# COMPARAISON
fig = pyplot.figure()
fig.suptitle('Comparaison des algorithmes')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# #### Learning Curve

# %%
from sklearn.model_selection import learning_curve

# %%
# lEARNING CURVE
train_sizes, train_scores, test_scores = learning_curve(LinearRegression(), X, y, cv=10, scoring='r2', n_jobs=-1, 
                                                        train_sizes=np.linspace(0.01, 1.0, 50))
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.subplots(1, figsize=(10,10))
plt.plot(train_sizes, train_mean, '--',  label="Training score")
plt.plot(train_sizes, test_mean,  label="Cross-validation score")

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std)

plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("r2 Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Prédiction Test Score

# %%
# prediction 
LR = LinearRegression()
y_pred = LR.fit(X_train, y_train).predict(X_test)
print("Test set score:",LR.score(X_test, y_test))
print( "Intercept:", LR.intercept_)
print ('Coefficients:', LR.coef_)
# Out:
# Test set score: 0.988217436777327
# Intercept: 0.000276768861319757
# Coefficients: [ 1.68059916e-17 -4.47466176e-04  8.39126540e-03  2.28638752e-02
#   7.45271859e-01  1.01089606e+00 -4.10672636e-04 -1.80728898e-02
#  -2.25379898e-03 -2.31278932e-04  1.47900529e-03  1.76054010e-03
#   2.71616079e-04  6.94223354e-04  2.46702753e-04  1.10863011e-03
#   1.54102394e-03 -2.85522102e-05 -3.70242362e-03  7.20117109e-04
#  -5.08144506e-04 -4.00601868e-04  2.74432153e-06  1.36527461e-03
#   1.02606174e-02  1.06154280e-04 -6.87426414e-04]

# %% [markdown]
# ### Features importance with SHAP

# %%
explainer = shap.LinearExplainer(LR, X)
shap_values = explainer.shap_values(X)

# %%
shap.summary_plot(shap_values, features=X, feature_names=X.columns)

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div id='iXUL5EUDBHBA8BRM4CO0D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap_values = explainer(X_test[:])

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.summary_plot(shap_values, features=X, feature_names=X.columns, plot_type='bar')

# %% [markdown]
# ## Variable dépendante : SiteEnergyUse(kBtu)

# %% [markdown]
# ### VIF (Variance Inflation Factor)

# %%
X=final_df.drop(['TotalGHGEmissions','SiteEnergyUse(kBtu)'],axis=1)
y= final_df['SiteEnergyUse(kBtu)']

# %%
z1=final_df.drop(['TotalGHGEmissions','SiteEnergyUse(kBtu)'],axis=1)
w1=final_df['SiteEnergyUse(kBtu)']

# %%
z1.replace([np.inf, -np.inf], 0, inplace=True)
w1.replace([np.inf, -np.inf], 0, inplace=True)
z1 = z1.fillna(z1.mean())
w1 = w1.fillna(w1.mean())

# %%
# Variance Inflation Factor (VIF)
vif_info = pd.DataFrame()
vif_info['VIF'] = [variance_inflation_factor(z1.values, i) for i in range(z1.shape[1])]
vif_info['Column'] = z1.columns 
vif_info.sort_values('VIF', ascending=False)
# Out:
#          VIF                                           Column
# 5   3.804517                                              Age
# 0   2.779710                                    OSEBuildingID
# 2   2.346548                                   NumberofFloors
# 21  2.136243  PrimaryPropertyType_Small- and Mid-Sized Office
# 10  1.941242                 PrimaryPropertyType_Large Office
# 14  1.884484                        PrimaryPropertyType_Other
# 1   1.685124                               PropertyGFAParking
# 24  1.576165                    PrimaryPropertyType_Warehouse
# 6   1.489798                     PrimaryPropertyType_Hospital
# 12  1.428845           PrimaryPropertyType_Mixed Use Property
# 25  1.353742             PrimaryPropertyType_Worship Facility
# 3   1.348630                                   SteamUse(kBtu)
# 8   1.338594                  PrimaryPropertyType_K-12 School
# 7   1.289916                        PrimaryPropertyType_Hotel
# ...

# %%
thresh = 5
final_variables =vif_info[vif_info['VIF']> thresh]
final_variables
# Out:
# Empty DataFrame
# Columns: [VIF, Column]
# Index: []

# %% [markdown]
# ### Test des Algorithmes

# %% [markdown]
# #### Training & testing set

# %%
X=final_df.drop(['TotalGHGEmissions','SiteEnergyUse(kBtu)'],axis=1)
y= final_df['SiteEnergyUse(kBtu)']

# %%
# paramètres 
test_size = 0.20
seed = 7
num_folds = 10
scoring = 'r2'
scoring1='neg_mean_squared_error'
param_grid =dict()
n_repeat=3
# Split Into Test and Training Sets
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=seed)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (1296, 26)
# (324, 26)
# (1296,)
# (324,)

# %% [markdown]
# ### Ordinary Least Squares (OLS) Regression In Statsmodels

# %%
#ajout d'une constante aux variables prédictives
X = sm.add_constant(X)

#fit linear regression model
model = sm.OLS(y,X)
results = model.fit()

#
print(results.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     SiteEnergyUse(kBtu)   R-squared:                       0.659
# Model:                             OLS   Adj. R-squared:                  0.654
# Method:                  Least Squares   F-statistic:                     118.5
# Date:                 Wed, 18 May 2022   Prob (F-statistic):               0.00
# Time:                         15:27:37   Log-Likelihood:                 4001.3
# No. Observations:                 1620   AIC:                            -7949.
# Df Residuals:                     1593   BIC:                            -7803.
# Df Model:                           26
# Covariance Type:             nonrobust
# ...
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Sckit-learn Algorithmes

# %%
# Algoritmes misent en comparaison
models = []
models.append(('LR', LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('RDG', Ridge()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('GBR', GradientBoostingRegressor()))
models.append(('ETR', ExtraTreesRegressor()))
models.append(('RFR', RandomForestRegressor()))
models.append(('XGBR', XGBRegressor()))

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=seed)

# %% [markdown]
# #### K-fold Cross validation & GridSearchCV

# %%
# Cross validation et GridSearchCV
results = []
names = []
for name, model in models:
    Kfold = RepeatedKFold(n_splits=num_folds,n_repeats=3, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=Kfold, scoring=scoring)
    cv_results1 = GridSearchCV(estimator=model,cv=Kfold,scoring='neg_mean_squared_error',
                               refit='neg_mean_squared_error',param_grid=param_grid,n_jobs = -1)
    grid = cv_results1.fit(X_train,y_train)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f) (%f)" % (name, absolute(grid.best_score_),cv_results.mean(), cv_results.std() )
    print(msg)
# Out:
# LR: 0.000839 (0.407522) (0.286729)
# LASSO: 0.001438 (-0.018651) (0.026594)
# RDG: 0.000910 (0.494341) (0.263175)
# EN: 0.001438 (-0.018651) (0.026594)
# KNN: 0.001213 (0.240785) (0.329681)
# CART: 0.001229 (0.056042) (1.903049)
# GBR: 0.000953 (0.376726) (0.918996)
# ETR: 0.000928 (0.503809) (0.496113)
# RFR: 0.000876 (0.423033) (0.646441)
# XGBR: 0.001197 (-0.174195) (2.712692)

# %% [markdown]
# #### Comparaison des algorithmes

# %%
# Pyplot : comparaison des algoritmes
fig = pyplot.figure()
fig.suptitle('Comparaison des algorithmes')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %% [markdown]
# #### Learning Curve

# %%
# lEARNING CURVE
train_sizes, train_scores, test_scores = learning_curve(ExtraTreesRegressor(), X, y, cv=10, scoring='r2', n_jobs=-1, 
                                                        train_sizes=np.linspace(0.01, 1.0, 50))
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.subplots(1, figsize=(8,8))
plt.plot(train_sizes, train_mean, '--',  label="Training score")
plt.plot(train_sizes, test_mean,  label="Cross-validation score")

plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std)

plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("r2 Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Prediction Test Score

# %%
# prediction 
ETR = ExtraTreesRegressor()
y_pred = ETR.fit(X_train, y_train).predict(X_test)
print("Test set score:",ETR.score(X_test, y_test))
# Out:
# Test set score: 0.832272309654666

# %% [markdown]
# ### Feature Importance using shap

# %%
explainer = shap.LinearExplainer(LR, X)
shap_values = explainer.shap_values(X)

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div id='iCK0G9O1W2PSAEI3LWUKW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.summary_plot(shap_values, features=X, feature_names=X.columns)

# %%
shap_values = explainer(X_test[:])

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.summary_plot(shap_values, features=X, feature_names=X.columns, plot_type='bar')

# %% [markdown]
# # Conclusion

# %% [raw]
# Pour effectuer des relevés d émission de co2 et la consommation d'énergie , nous pouvons utiliser l’algorithme linear Regression comme model et surtout nous pourrions mettre l’accent sur la variabilité des deux facteurs majeurs qui sont le gaz, le steam, et le nombre d’étage contrairement à Energy star score qui n'apporte pas de résultats pertinents à cause du score élevé de la majorité des bâtiments hors multifamily.
# En ce qui concerne Site Energy use , il est préférable d'utiliser l’algorithme Extra Trees Regressor.
# D’autres facteurs mineurs sur les prédictions , néanmoins  ils restent important dans la prédiction des deux variables , sont l'âge et property GFA Parking.
